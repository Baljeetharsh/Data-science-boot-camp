# %%
import pandas as pd

# %%
import requests

# %%
import json

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
js = res.json()

# %%
type(res)
# Out:
# requests.models.Response

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49741',
#   'id': 1452657672,
#   'node_id': 'PR_kwDOAA0YD85DFEXQ',
#   'number': 49741,
#   'title': 'Initialize row data frame with list',
#   'user': {'login': 'lucaslarios',
#    'id': 66137619,
#    'node_id': 'MDQ6VXNlcjY2MTM3NjE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66137619?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lucaslarios',
#    'html_url': 'https://github.com/lucaslarios',
# ...

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/49741',
#  'id': 1452657672,
#  'node_id': 'PR_kwDOAA0YD85DFEXQ',
#  'number': 49741,
#  'title': 'Initialize row data frame with list',
#  'user': {'login': 'lucaslarios',
#   'id': 66137619,
#   'node_id': 'MDQ6VXNlcjY2MTM3NjE5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/66137619?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lucaslarios',
#   'html_url': 'https://github.com/lucaslarios',
#   'followers_url': 'https://api.github.com/users/lucaslarios/followers',
# ...

# %%
js[0]['title']
# Out:
# 'Initialize row data frame with list'

# %%
len(js)
# Out:
# 30

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# Initialize row data frame with list
# CLN: Fix pylint undefined-loop-variable warnings
# DOC: Provide examples of using read_parquet
# BUG: Fixes dataFrame to_string(header=False)
# ENH: infer Timestamp(iso8601string) resolution
# Fix: Treat Generic classes as not being is_list_like
# Revert "Add 'color' and 'size' to arguments (#44856)"
# BUG: Plotly scatter plots no longer produce color correctly, color alias for c in 1.5
# PERF: assigning in a for loop
# Improve type hint accuracy for read_sql_query
# CLN: enable pylint's redefined-outer-name in pandas/core/resample.py
# BUG:  hrules and clines in .to_latex() draw two lines at bottom of table
# PERF: Series.fillna for pyarrow-backed dtypes
# An optional parameter called check_series_type was created
# ENH: DatetimeProperties results seem to be inconsistent since missing milliseconds #49073
# REF: use sanitize_array in Index.__new__
# BUG: pandas.read_sql_query type hint only allows str params
# API: dtlike.astype(inty)
# ...

# %%
pd.DataFrame(js,columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49741/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49741',
#   'id': 1452657672,
#   'node_id': 'PR_kwDOAA0YD85DFEXQ',
#   'number': 49741,
#   'title': 'Initialize row data frame with list',
#   'user': {'login': 'lucaslarios',
#    'id': 66137619,
#    'node_id': 'MDQ6VXNlcjY2MTM3NjE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66137619?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lucaslarios',
#    'html_url': 'https://github.com/lucaslarios',
# ...

# %%
df4=pd.DataFrame(js)

# %%
type(f)
# Out:
# pandas.core.frame.DataFrame

# %%
df4
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df4.to_csv('jason_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'Leviob',
#  'id': 59812528,
#  'node_id': 'MDQ6VXNlcjU5ODEyNTI4',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/59812528?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Leviob',
#  'html_url': 'https://github.com/Leviob',
#  'followers_url': 'https://api.github.com/users/Leviob/followers',
#  'following_url': 'https://api.github.com/users/Leviob/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Leviob/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Leviob/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Leviob/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Leviob/orgs',
#  'repos_url': 'https://api.github.com/users/Leviob/repos',
#  'events_url': 'https://api.github.com/users/Leviob/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Leviob/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
t=[]
for i in range(len(js)):
    t.append(js[i]['user'])

pd.DataFrame(t)
# Out:
#              login         id               node_id  \
# 0      lucaslarios   66137619  MDQ6VXNlcjY2MTM3NjE5
# 1           Leviob   59812528  MDQ6VXNlcjU5ODEyNTI4
# 2        wjones127    5488879  MDQ6VXNlcjU0ODg4Nzk=
# 3   andrewchen1216   55290810  MDQ6VXNlcjU1MjkwODEw
# 4     jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 5           Dr-Irv   15113894  MDQ6VXNlcjE1MTEzODk0
# 6            phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 7        astrowonk   13702392  MDQ6VXNlcjEzNzAyMzky
# 8          Saelyos   34129209  MDQ6VXNlcjM0MTI5MjA5
# 9        xuganyu96   25167432  MDQ6VXNlcjI1MTY3NDMy
# 10   calhockemeyer   74273035  MDQ6VXNlcjc0MjczMDM1
# 11     StevenLi-DS   33796896  MDQ6VXNlcjMzNzk2ODk2
# 12      lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 13     lucaslarios   66137619  MDQ6VXNlcjY2MTM3NjE5
# 14     PedroPUCRIO  109247450          U_kgDOBoL72g
# 15    jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 16       johndoe28   26770569  MDQ6VXNlcjI2NzcwNTY5
# ...

# %%
type(t)
# Out:
# list

# %%
t[0]
# Out:
# {'login': 'lucaslarios',
#  'id': 66137619,
#  'node_id': 'MDQ6VXNlcjY2MTM3NjE5',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/66137619?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/lucaslarios',
#  'html_url': 'https://github.com/lucaslarios',
#  'followers_url': 'https://api.github.com/users/lucaslarios/followers',
#  'following_url': 'https://api.github.com/users/lucaslarios/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/lucaslarios/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/lucaslarios/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/lucaslarios/subscriptions',
#  'organizations_url': 'https://api.github.com/users/lucaslarios/orgs',
#  'repos_url': 'https://api.github.com/users/lucaslarios/repos',
#  'events_url': 'https://api.github.com/users/lucaslarios/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/lucaslarios/received_events',
# ...

# %%
form_file = pd.read_csv(r"C:\Users\baljeet kaur\jason_dump.csv")

# %%
form_file.to_pickle("my_pickle")

# %%
pwd()
# Out:
# 'C:\\Users\\baljeet kaur'
